# %%
from pyspark.sql import SparkSession, Window
from pyspark.sql import functions as F
from pyspark.sql import types as T
from datetime import datetime
import json

# Initialize Spark Session (without Delta configurations)
spark = SparkSession.builder \
    .appName("F1SilverLayer") \
    .getOrCreate()

# First, let's read the parquet files and see what we're working with
def process_f1_silver_layer():
    try:
        print("Starting Silver Layer Processing...")

        # Read the parquet files
        bronze_df = spark.read.json(
            "/content/drive/MyDrive/Capstone/bronze/season=*"
        )

        print("Bronze data loaded. Starting transformations...")

        # 1. Explode nested structures
        df = bronze_df.select(
            F.col("season"),
            F.col("round"),
            F.col("raceName"),
            F.col("date"),
            F.col("time"),
            F.col("url"),
            F.col("Circuit").alias("circuit"),
            F.explode("Results").alias("result")
        )

        # 2. Flatten nested structures
        df = df.select(
            "*",
            F.col("circuit.circuitId").alias("circuit_id"),
            F.col("circuit.circuitName").alias("circuit_name"),
            F.col("circuit.Location.lat").alias("circuit_lat"),
            F.col("circuit.Location.long").alias("circuit_long"),
            F.col("circuit.Location.locality").alias("circuit_locality"),
            F.col("circuit.Location.country").alias("circuit_country"),
            F.col("result.Constructor.constructorId").alias("constructor_id"),
            F.col("result.Constructor.name").alias("constructor_name"),
            F.col("result.Driver.driverId").alias("driver_id"),
            F.col("result.Driver.givenName").alias("driver_given_name"),
            F.col("result.Driver.familyName").alias("driver_family_name"),
            F.col("result.position").alias("position"),
            F.col("result.points").alias("points"),
            F.col("result.grid").alias("grid"),
            F.col("result.laps").alias("laps"),
            F.col("result.status").alias("status"),
            F.col("result.Time.time").alias("finish_time")
        ).drop("circuit", "result")

        # 3. Data type conversions and standardization
        df = df.withColumn("race_timestamp",
                          F.to_timestamp(
                              F.concat(F.col("date"), F.lit(" "), F.col("time")),
                              "yyyy-MM-dd HH:mm:ssX"
                          ))

        # 4. Add computed columns
        df = df.withColumn("driver_full_name",
                          F.concat(F.col("driver_given_name"),
                                 F.lit(" "),
                                 F.col("driver_family_name")))

        # 5. Data quality checks
        df = df.withColumn("is_valid_position",
                          (F.col("position").isNotNull() &
                           F.col("position").cast("int").isNotNull() &
                           (F.col("position").cast("int") >= 1)))

        df = df.withColumn("is_valid_points",
                          (F.col("points").isNotNull() &
                           F.col("points").cast("double").isNotNull() &
                           (F.col("points").cast("double") >= 0)))

        df = df.withColumn("is_valid_grid",
                          (F.col("grid").isNotNull() &
                           F.col("grid").cast("int").isNotNull() &
                           (F.col("grid").cast("int") >= 0)))

        df = df.withColumn("is_valid_date",
                          F.col("race_timestamp").isNotNull())

        # Combine all checks
        df = df.withColumn("is_valid_record",
                          F.col("is_valid_position") &
                          F.col("is_valid_points") &
                          F.col("is_valid_grid") &
                          F.col("is_valid_date"))

        # 6. Add metadata
        df = df.withColumn("processed_timestamp", F.current_timestamp())

        # 7. Calculate quality metrics
        total_records = df.count()
        valid_records = df.filter(F.col("is_valid_record")).count()
        null_percentages = {}

        for column in df.columns:
            null_count = df.filter(F.col(column).isNull()).count()
            null_percentages[column] = (null_count / total_records) * 100

        print("\nData Quality Metrics:")
        print(f"Total Records: {total_records}")
        print(f"Valid Records: {valid_records}")
        print(f"Invalid Records: {total_records - valid_records}")
        print("\nNull Percentages:")
        for col, pct in null_percentages.items():
            if pct > 0:
                print(f"{col}: {pct:.2f}%")

        # 8. Write to silver layer
        print("\nWriting to silver layer...")

        # Write main dataset
        silver_path = "/content/drive/MyDrive/Capstone/silver1"
        df.write.mode("overwrite") \
            .partitionBy("season") \
            .parquet(silver_path)

        print(f"\nSilver layer data written to: {silver_path}")
        print("Silver Layer Processing Complete!")

        return df

    except Exception as e:
        print(f"Error in Silver Layer Processing: {str(e)}")
        raise

# Execute the processing
silver_df = process_f1_silver_layer()

# Show sample of the processed data
print("\nSample of processed data:")
silver_df.show(5)

# %%
from pyspark.sql import SparkSession, Window
from pyspark.sql import functions as F
from pyspark.sql import types as T
from datetime import datetime
import json

# Initialize Spark Session (without Delta configurations)
spark = SparkSession.builder \
    .appName("F1SilverLayer") \
    .getOrCreate()

bronze_df = spark.read.json(
            "/content/drive/MyDrive/Capstone/bronze/season=*"
        )

# %%
bronze_df.show()
# Out:
# +--------------------+--------------------+----------+--------------------+--------------------+-----+------+-----------+---------+--------------------+
# |             Circuit|             Results|      date| ingestion_timestamp|            raceName|round|season|     source|     time|                 url|
# +--------------------+--------------------+----------+--------------------+--------------------+-----+------+-----------+---------+--------------------+
# |{{Bahrain, 26.032...|[{{red_bull, Red ...|2024-03-02|2025-04-16T07:19:...|  Bahrain Grand Prix|    1|  2024|jolpica_api|15:00:00Z|https://en.wikipe...|
# |{{Saudi Arabia, 2...|[{{red_bull, Red ...|2024-03-09|2025-04-16T07:19:...|Saudi Arabian Gra...|    2|  2024|jolpica_api|17:00:00Z|https://en.wikipe...|
# |{{Australia, -37....|[{{ferrari, Ferra...|2024-03-24|2025-04-16T07:19:...|Australian Grand ...|    3|  2024|jolpica_api|04:00:00Z|https://en.wikipe...|
# |{{Japan, 34.8431,...|[{{red_bull, Red ...|2024-04-07|2025-04-16T07:19:...| Japanese Grand Prix|    4|  2024|jolpica_api|05:00:00Z|https://en.wikipe...|
# |{{China, 31.3389,...|[{{red_bull, Red ...|2024-04-21|2025-04-16T07:19:...|  Chinese Grand Prix|    5|  2024|jolpica_api|07:00:00Z|https://en.wikipe...|
# |{{USA, 25.9581, M...|[{{mclaren, McLar...|2024-05-05|2025-04-16T07:19:...|    Miami Grand Prix|    6|  2024|jolpica_api|20:00:00Z|https://en.wikipe...|
# |{{USA, 25.9581, M...|[{{red_bull, Red ...|2024-05-05|2025-04-16T07:19:...|    Miami Grand Prix|    6|  2024|jolpica_api|20:00:00Z|https://en.wikipe...|
# |{{Italy, 44.3439,...|[{{red_bull, Red ...|2024-05-19|2025-04-16T07:19:...|Emilia Romagna Gr...|    7|  2024|jolpica_api|13:00:00Z|https://en.wikipe...|
# |{{Monaco, 43.7347...|[{{ferrari, Ferra...|2024-05-26|2025-04-16T07:19:...|   Monaco Grand Prix|    8|  2024|jolpica_api|13:00:00Z|https://en.wikipe...|
# |{{Canada, 45.5, M...|[{{red_bull, Red ...|2024-06-09|2025-04-16T07:19:...| Canadian Grand Prix|    9|  2024|jolpica_api|18:00:00Z|https://en.wikipe...|
# |{{Spain, 41.57, M...|[{{red_bull, Red ...|2024-06-23|2025-04-16T07:19:...|  Spanish Grand Prix|   10|  2024|jolpica_api|13:00:00Z|https://en.wikipe...|
# |{{Austria, 47.219...|[{{mercedes, Merc...|2024-06-30|2025-04-16T07:19:...| Austrian Grand Prix|   11|  2024|jolpica_api|13:00:00Z|https://en.wikipe...|
# |{{Austria, 47.219...|[{{mclaren, McLar...|2024-06-30|2025-04-16T07:19:...| Austrian Grand Prix|   11|  2024|jolpica_api|13:00:00Z|https://en.wikipe...|
# |{{UK, 52.0786, Si...|[{{mercedes, Merc...|2024-07-07|2025-04-16T07:19:...|  British Grand Prix|   12|  2024|jolpica_api|14:00:00Z|https://en.wikipe...|
# |{{Hungary, 47.578...|[{{mclaren, McLar...|2024-07-21|2025-04-16T07:19:...|Hungarian Grand Prix|   13|  2024|jolpica_api|13:00:00Z|https://en.wikipe...|
# |{{Belgium, 50.437...|[{{mercedes, Merc...|2024-07-28|2025-04-16T07:19:...|  Belgian Grand Prix|   14|  2024|jolpica_api|13:00:00Z|https://en.wikipe...|
# |{{Netherlands, 52...|[{{mclaren, McLar...|2024-08-25|2025-04-16T07:19:...|    Dutch Grand Prix|   15|  2024|jolpica_api|13:00:00Z|https://en.wikipe...|
# |{{Italy, 45.6156,...|[{{ferrari, Ferra...|2024-09-01|2025-04-16T07:19:...|  Italian Grand Prix|   16|  2024|jolpica_api|13:00:00Z|https://en.wikipe...|
# |{{Italy, 45.6156,...|[{{mclaren, McLar...|2024-09-01|2025-04-16T07:19:...|  Italian Grand Prix|   16|  2024|jolpica_api|13:00:00Z|https://en.wikipe...|
# |{{Azerbaijan, 40....|[{{mclaren, McLar...|2024-09-15|2025-04-16T07:19:...|Azerbaijan Grand ...|   17|  2024|jolpica_api|11:00:00Z|https://en.wikipe...|
# +--------------------+--------------------+----------+--------------------+--------------------+-----+------+-----------+---------+--------------------+
# only showing top 20 rows

# %%
bronze_df.repartition(1).write.parquet('/content/drive/MyDrive/Capstone/tmp')

# %%
import pandas as pd
import pyarrow.parquet as pq
import os
import json
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, explode, expr, lit

# Initialize Spark session with appropriate configurations for Jupyter
spark = SparkSession.builder \
    .appName("F1 Data Transformation") \
    .config("spark.driver.memory", "4g") \
    .config("spark.ui.port", "4050") \
    .config("spark.driver.host", "localhost") \
    .master("local[*]") \
    .getOrCreate()

# File paths - update these to your actual file locations
output_path = "/content/drive/MyDrive/Capstone/tmp"

# OPTION 1: If PySpark can directly read the parquet file
try:
    # Try direct reading with PySpark
    df_parquet = spark.read.json("/content/drive/MyDrive/Capstone/bronze/season=*")
    print("Successfully read parquet file directly with PySpark")
except Exception as e:
    print(f"Direct PySpark read failed: {e}")
    print("Falling back to pandas + pyarrow method")


# Display schema and sample data
print("\\nParquet file schema:")
df_parquet.printSchema()

print("\\nSample data from parquet file:")
df_parquet.show(2, truncate=False)

# Explode the Results array to create one row per driver result
df_exploded = df_parquet.select(
    col("season"),
    col("round"),
    col("url").alias("race_url"),
    col("raceName"),
    col("date"),
    col("time"),
    col("Circuit.circuitId").alias("circuitId"),
    col("Circuit.url").alias("circuit_url"),
    col("Circuit.circuitName").alias("circuitName"),
    col("Circuit.Location.lat").alias("circuit_lat"),
    col("Circuit.Location.long").alias("circuit_long"),
    col("Circuit.Location.locality").alias("circuit_locality"),
    col("Circuit.Location.country").alias("circuit_country"),
    explode(col("Results")).alias("result")
)

# Extract fields from the exploded result
df_flattened = df_exploded.select(
    col("season"),
    col("round"),
    col("race_url"),
    col("raceName"),
    col("date"),
    col("time"),
    col("circuitId"),
    col("circuit_url"),
    col("circuitName"),
    col("circuit_lat"),
    col("circuit_long"),
    col("circuit_locality"),
    col("circuit_country"),
    col("result.number").alias("driverNumber"),
    col("result.position").alias("position"),
    col("result.positionText").alias("positionText"),
    col("result.points").alias("points"),
    col("result.grid").alias("grid"),
    col("result.laps").alias("laps"),
    col("result.status").alias("status"),
    col("result.Time.time").alias("raceTime"),
    col("result.Time.millis").alias("raceTimeMillis"),
    col("result.Driver.driverId").alias("driverId"),
    col("result.Driver.permanentNumber").alias("permanentNumber"),
    col("result.Driver.code").alias("code"),
    col("result.Driver.url").alias("driver_url"),
    col("result.Driver.givenName").alias("givenName"),
    col("result.Driver.familyName").alias("familyName"),
    col("result.Driver.dateOfBirth").alias("dateOfBirth"),
    col("result.Driver.nationality").alias("driver_nationality"),
    col("result.Constructor.constructorId").alias("constructorId"),
    col("result.Constructor.url").alias("constructor_url"),
    col("result.Constructor.name").alias("constructorName"),
    col("result.Constructor.nationality").alias("constructor_nationality"),
    col("result.FastestLap.rank").alias("fastestLapRank"),
    col("result.FastestLap.lap").alias("fastestLapNumber"),
    col("result.FastestLap.Time.time").alias("fastestLapTime"),
    col("result.FastestLap.AverageSpeed.speed").alias("fastestLapAvgSpeed"),
    col("result.FastestLap.AverageSpeed.units").alias("fastestLapSpeedUnits")
)

# Show the flattened data
print("\\nFlattened data schema:")
df_flattened.printSchema()

print("\\nFlattened data sample (first 2 rows):")
df_flattened.show(2, truncate=False)

# Count the number of rows
row_count = df_flattened.count()
print(f"\\nTotal number of rows in flattened data: {row_count}")



df_flattened.repartition(1).write.mode("overwrite").option("header", "true").csv(f"{output_path}/csv")
# Out:
# Successfully read parquet file directly with PySpark
# \nParquet file schema:
# root
#  |-- Circuit: struct (nullable = true)
#  |    |-- Location: struct (nullable = true)
#  |    |    |-- country: string (nullable = true)
#  |    |    |-- lat: string (nullable = true)
#  |    |    |-- locality: string (nullable = true)
#  |    |    |-- long: string (nullable = true)
#  |    |-- circuitId: string (nullable = true)
#  |    |-- circuitName: string (nullable = true)
#  |    |-- url: string (nullable = true)
#  |-- Results: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- Constructor: struct (nullable = true)
#  |    |    |    |-- constructorId: string (nullable = true)
#  |    |    |    |-- name: string (nullable = true)
#  |    |    |    |-- nationality: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- Driver: struct (nullable = true)
#  |    |    |    |-- code: string (nullable = true)
#  |    |    |    |-- dateOfBirth: string (nullable = true)
#  |    |    |    |-- driverId: string (nullable = true)
#  |    |    |    |-- familyName: string (nullable = true)
#  |    |    |    |-- givenName: string (nullable = true)
#  |    |    |    |-- nationality: string (nullable = true)
#  |    |    |    |-- permanentNumber: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- FastestLap: struct (nullable = true)
#  |    |    |    |-- AverageSpeed: struct (nullable = true)
#  |    |    |    |    |-- speed: string (nullable = true)
#  |    |    |    |    |-- units: string (nullable = true)
#  |    |    |    |-- Time: struct (nullable = true)
#  |    |    |    |    |-- time: string (nullable = true)
#  |    |    |    |-- lap: string (nullable = true)
#  |    |    |    |-- rank: string (nullable = true)
#  |    |    |-- Time: struct (nullable = true)
#  |    |    |    |-- millis: string (nullable = true)
#  |    |    |    |-- time: string (nullable = true)
#  |    |    |-- grid: string (nullable = true)
#  |    |    |-- laps: string (nullable = true)
#  |    |    |-- number: string (nullable = true)
#  |    |    |-- points: string (nullable = true)
#  |    |    |-- position: string (nullable = true)
#  |    |    |-- positionText: string (nullable = true)
#  |    |    |-- status: string (nullable = true)
#  |-- date: string (nullable = true)
#  |-- ingestion_timestamp: string (nullable = true)
#  |-- raceName: string (nullable = true)
#  |-- round: string (nullable = true)
#  |-- season: long (nullable = true)
#  |-- source: string (nullable = true)
#  |-- time: string (nullable = true)
#  |-- url: string (nullable = true)
#
# \nSample data from parquet file:
# +------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |Circuit                                                                                                                                   |Results                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# +------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |{{Bahrain, 26.0325, Sakhir, 50.5106}, bahrain, Bahrain International Circuit, https://en.wikipedia.org/wiki/Bahrain_International_Circuit}|[{{red_bull, Red Bull, Austrian, http://en.wikipedia.org/wiki/Red_Bull_Racing}, {VER, 1997-09-30, max_verstappen, Verstappen, Max, Dutch, 33, http://en.wikipedia.org/wiki/Max_Verstappen}, {{210.383, kph}, {1:32.608}, 39, 1}, {5504742, 1:31:44.742}, 1, 57, 1, 26, 1, 1, Finished}, {{red_bull, Red Bull, Austrian, http://en.wikipedia.org/wiki/Red_Bull_Racing}, {PER, 1990-01-26, perez, Pérez, Sergio, Mexican, 11, http://en.wikipedia.org/wiki/Sergio_P%C3%A9rez}, {{206.468, kph}, {1:34.364}, 40, 4}, {5527199, +22.457}, 5, 57, 11, 18, 2, 2, Finished}, {{ferrari, Ferrari, Italian, http://en.wikipedia.org/wiki/Scuderia_Ferrari}, {SAI, 1994-09-01, sainz, Sainz, Carlos, Spanish, 55, http://en.wikipedia.org/wiki/Carlos_Sainz_Jr.}, {{206.156, kph}, {1:34.507}, 44, 6}, {5529852, +25.110}, 4, 57, 55, 15, 3, 3, Finished}, {{ferrari, Ferrari, Italian, http://en.wikipedia.org/wiki/Scuderia_Ferrari}, {LEC, 1997-10-16, leclerc, Leclerc, Charles, Monegasque, 16, http://en.wikipedia.org/wiki/Charles_Leclerc}, {{207.069, kph}, {1:34.090}, 36, 2}, {5544411, +39.669}, 2, 57, 16, 12, 4, 4, Finished}, {{mercedes, Mercedes, German, http://en.wikipedia.org/wiki/Mercedes-Benz_in_Formula_One}, {RUS, 1998-02-15, russell, Russell, George, British, 63, http://en.wikipedia.org/wiki/George_Russell_(racing_driver)}, {{204.946, kph}, {1:35.065}, 40, 12}, {5551530, +46.788}, 3, 57, 63, 10, 5, 5, Finished}, {{mclaren, McLaren, British, http://en.wikipedia.org/wiki/McLaren}, {NOR, 1999-11-13, norris, Norris, Lando, British, 4, http://en.wikipedia.org/wiki/Lando_Norris}, {NULL, {1:34.476}, 35, 5}, {5553200, +48.458}, 7, 57, 4, 8, 6, 6, Finished}, {{mercedes, Mercedes, German, http://en.wikipedia.org/wiki/Mercedes-Benz_in_Formula_One}, {HAM, 1985-01-07, hamilton, Hamilton, Lewis, British, 44, http://en.wikipedia.org/wiki/Lewis_Hamilton}, {{205.688, kph}, {1:34.722}, 39, 7}, {5555066, +50.324}, 9, 57, 44, 6, 7, 7, Finished}, {{mclaren, McLaren, British, http://en.wikipedia.org/wiki/McLaren}, {PIA, 2001-04-06, piastri, Piastri, Oscar, Australian, 81, http://en.wikipedia.org/wiki/Oscar_Piastri}, {NULL, {1:34.983}, 39, 11}, {5560824, +56.082}, 8, 57, 81, 4, 8, 8, Finished}, {{aston_martin, Aston Martin, British, http://en.wikipedia.org/wiki/Aston_Martin_in_Formula_One}, {ALO, 1981-07-29, alonso, Alonso, Fernando, Spanish, 14, http://en.wikipedia.org/wiki/Fernando_Alonso}, {{206.830, kph}, {1:34.199}, 48, 3}, {5579629, +1:14.887}, 6, 57, 14, 2, 9, 9, Finished}, {{aston_martin, Aston Martin, British, http://en.wikipedia.org/wiki/Aston_Martin_in_Formula_One}, {STR, 1998-10-29, stroll, Stroll, Lance, Canadian, 18, http://en.wikipedia.org/wiki/Lance_Stroll}, {{203.730, kph}, {1:35.632}, 30, 16}, {5597958, +1:33.216}, 12, 57, 18, 1, 10, 10, Finished}, {{sauber, Sauber, Swiss, http://en.wikipedia.org/wiki/Sauber_Motorsport}, {ZHO, 1999-05-30, zhou, Zhou, Guanyu, Chinese, 24, http://en.wikipedia.org/wiki/Zhou_Guanyu}, {{204.102, kph}, {1:35.458}, 30, 14}, {5511501, +6.759}, 17, 56, 24, 0, 11, 11, Lapped}, {{haas, Haas F1 Team, American, http://en.wikipedia.org/wiki/Haas_F1_Team}, {MAG, 1992-10-05, kevin_magnussen, Magnussen, Kevin, Danish, 20, http://en.wikipedia.org/wiki/Kevin_Magnussen}, {{203.863, kph}, {1:35.570}, 34, 15}, {5513058, +8.316}, 15, 56, 20, 0, 12, 12, Lapped}, {{rb, RB F1 Team, Italian, http://en.wikipedia.org/wiki/RB_Formula_One_Team}, {RIC, 1989-07-01, ricciardo, Ricciardo, Daniel, Australian, 3, http://en.wikipedia.org/wiki/Daniel_Ricciardo}, {{204.735, kph}, {1:35.163}, 37, 13}, {5513700, +8.958}, 14, 56, 3, 0, 13, 13, Lapped}, {{rb, RB F1 Team, Italian, http://en.wikipedia.org/wiki/RB_Formula_One_Team}, {TSU, 2000-05-11, tsunoda, Tsunoda, Yuki, Japanese, 22, http://en.wikipedia.org/wiki/Yuki_Tsunoda}, {{203.303, kph}, {1:35.833}, 37, 18}, {5514224, +9.482}, 11, 56, 22, 0, 14, 14, Lapped}, {{williams, Williams, British, htt ...
# |{{Saudi Arabia, 21.6319, Jeddah, 39.1044}, jeddah, Jeddah Corniche Circuit, https://en.wikipedia.org/wiki/Jeddah_Corniche_Circuit}        |[{{red_bull, Red Bull, Austrian, http://en.wikipedia.org/wiki/Red_Bull_Racing}, {VER, 1997-09-30, max_verstappen, Verstappen, Max, Dutch, 33, http://en.wikipedia.org/wiki/Max_Verstappen}, {{242.188, kph}, {1:31.773}, 50, 3}, {4843273, 1:20:43.273}, 1, 50, 1, 25, 1, 1, Finished}, {{red_bull, Red Bull, Austrian, http://en.wikipedia.org/wiki/Red_Bull_Racing}, {PER, 1990-01-26, perez, Pérez, Sergio, Mexican, 11, http://en.wikipedia.org/wiki/Sergio_P%C3%A9rez}, {{240.876, kph}, {1:32.273}, 37, 8}, {4856916, +13.643}, 3, 50, 11, 18, 2, 2, Finished}, {{ferrari, Ferrari, Italian, http://en.wikipedia.org/wiki/Scuderia_Ferrari}, {LEC, 1997-10-16, leclerc, Leclerc, Charles, Monegasque, 16, http://en.wikipedia.org/wiki/Charles_Leclerc}, {{242.561, kph}, {1:31.632}, 50, 1}, {4861912, +18.639}, 2, 50, 16, 16, 3, 3, Finished}, {{mclaren, McLaren, British, http://en.wikipedia.org/wiki/McLaren}, {PIA, 2001-04-06, piastri, Piastri, Oscar, Australian, 81, http://en.wikipedia.org/wiki/Oscar_Piastri}, {NULL, {1:32.310}, 45, 10}, {4875280, +32.007}, 5, 50, 81, 12, 4, 4, Finished}, {{aston_martin, Aston Martin, British, http://en.wikipedia.org/wiki/Aston_Martin_in_Formula_One}, {ALO, 1981-07-29, alonso, Alonso, Fernando, Spanish, 14, http://en.wikipedia.org/wiki/Fernando_Alonso}, {{240.579, kph}, {1:32.387}, 43, 13}, {4879032, +35.759}, 4, 50, 14, 10, 5, 5, Finished}, {{mercedes, Mercedes, German, http://en.wikipedia.org/wiki/Mercedes-Benz_in_Formula_One}, {RUS, 1998-02-15, russell, Russell, George, British, 63, http://en.wikipedia.org/wiki/George_Russell_(racing_driver)}, {{240.926, kph}, {1:32.254}, 42, 7}, {4883209, +39.936}, 7, 50, 63, 8, 6, 6, Finished}, {{ferrari, Ferrari, Italian, http://en.wikipedia.org/wiki/Scuderia_Ferrari}, {BEA, 2005-05-08, bearman, Bearman, Oliver, British, 87, http://en.wikipedia.org/wiki/Oliver_Bearman}, {{241.103, kph}, {1:32.186}, 50, 5}, {4885952, +42.679}, 11, 50, 38, 6, 7, 7, Finished}, {{mclaren, McLaren, British, http://en.wikipedia.org/wiki/McLaren}, {NOR, 1999-11-13, norris, Norris, Lando, British, 4, http://en.wikipedia.org/wiki/Lando_Norris}, {NULL, {1:31.944}, 40, 4}, {4888981, +45.708}, 6, 50, 4, 4, 8, 8, Finished}, {{mercedes, Mercedes, German, http://en.wikipedia.org/wiki/Mercedes-Benz_in_Formula_One}, {HAM, 1985-01-07, hamilton, Hamilton, Lewis, British, 44, http://en.wikipedia.org/wiki/Lewis_Hamilton}, {{242.260, kph}, {1:31.746}, 38, 2}, {4890664, +47.391}, 8, 50, 44, 2, 9, 9, Finished}, {{haas, Haas F1 Team, American, http://en.wikipedia.org/wiki/Haas_F1_Team}, {HUL, 1987-08-19, hulkenberg, Hülkenberg, Nico, German, 27, http://en.wikipedia.org/wiki/Nico_H%C3%BClkenberg}, {{240.633, kph}, {1:32.366}, 49, 12}, {4920269, +1:16.996}, 15, 50, 27, 1, 10, 10, Finished}, {{williams, Williams, British, http://en.wikipedia.org/wiki/Williams_Grand_Prix_Engineering}, {ALB, 1996-03-23, albon, Albon, Alexander, Thai, 23, http://en.wikipedia.org/wiki/Alexander_Albon}, {{240.787, kph}, {1:32.307}, 50, 9}, {4931627, +1:28.354}, 12, 50, 23, 0, 11, 11, Finished}, {{haas, Haas F1 Team, American, http://en.wikipedia.org/wiki/Haas_F1_Team}, {MAG, 1992-10-05, kevin_magnussen, Magnussen, Kevin, Danish, 20, http://en.wikipedia.org/wiki/Kevin_Magnussen}, {{240.706, kph}, {1:32.338}, 47, 11}, {4949010, +1:45.737}, 13, 50, 20, 0, 12, 12, Finished}, {{alpine, Alpine F1 Team, French, http://en.wikipedia.org/wiki/Alpine_F1_Team}, {OCO, 1996-09-17, ocon, Ocon, Esteban, French, 31, http://en.wikipedia.org/wiki/Esteban_Ocon}, {{237.763, kph}, {1:33.481}, 48, 17}, {4847274, +4.001}, 17, 49, 31, 0, 13, 13, Lapped}, {{williams, Williams, British, http://en.wikipedia.org/wiki/Williams_Grand_Prix_Engineering}, {SAR, 2000-12-31, sargeant, Sargeant, Logan, American, 2, http://en.wikipedia.org/wiki/Logan_Sargeant}, {NULL, {1:33.026}, 49, 15}, {4850058, +6.785}, 19, 49, 2, 0, 14, 14, Lapped}, {{rb, RB F1 ...
# +------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# only showing top 2 rows
#
# \nFlattened data schema:
# root
#  |-- season: long (nullable = true)
#  |-- round: string (nullable = true)
#  |-- race_url: string (nullable = true)
#  |-- raceName: string (nullable = true)
#  |-- date: string (nullable = true)
#  |-- time: string (nullable = true)
#  |-- circuitId: string (nullable = true)
#  |-- circuit_url: string (nullable = true)
#  |-- circuitName: string (nullable = true)
#  |-- circuit_lat: string (nullable = true)
#  |-- circuit_long: string (nullable = true)
#  |-- circuit_locality: string (nullable = true)
#  |-- circuit_country: string (nullable = true)
#  |-- driverNumber: string (nullable = true)
#  |-- position: string (nullable = true)
#  |-- positionText: string (nullable = true)
#  |-- points: string (nullable = true)
#  |-- grid: string (nullable = true)
#  |-- laps: string (nullable = true)
#  |-- status: string (nullable = true)
#  |-- raceTime: string (nullable = true)
#  |-- raceTimeMillis: string (nullable = true)
#  |-- driverId: string (nullable = true)
#  |-- permanentNumber: string (nullable = true)
#  |-- code: string (nullable = true)
#  |-- driver_url: string (nullable = true)
#  |-- givenName: string (nullable = true)
#  |-- familyName: string (nullable = true)
#  |-- dateOfBirth: string (nullable = true)
#  |-- driver_nationality: string (nullable = true)
#  |-- constructorId: string (nullable = true)
#  |-- constructor_url: string (nullable = true)
#  |-- constructorName: string (nullable = true)
#  |-- constructor_nationality: string (nullable = true)
#  |-- fastestLapRank: string (nullable = true)
#  |-- fastestLapNumber: string (nullable = true)
#  |-- fastestLapTime: string (nullable = true)
#  |-- fastestLapAvgSpeed: string (nullable = true)
#  |-- fastestLapSpeedUnits: string (nullable = true)
#
# \nFlattened data sample (first 2 rows):
# +------+-----+-----------------------------------------------------+------------------+----------+---------+---------+-----------------------------------------------------------+-----------------------------+-----------+------------+----------------+---------------+------------+--------+------------+------+----+----+--------+-----------+--------------+--------------+---------------+----+----------------------------------------------+---------+----------+-----------+------------------+-------------+--------------------------------------------+---------------+-----------------------+--------------+----------------+--------------+------------------+--------------------+
# |season|round|race_url                                             |raceName          |date      |time     |circuitId|circuit_url                                                |circuitName                  |circuit_lat|circuit_long|circuit_locality|circuit_country|driverNumber|position|positionText|points|grid|laps|status  |raceTime   |raceTimeMillis|driverId      |permanentNumber|code|driver_url                                    |givenName|familyName|dateOfBirth|driver_nationality|constructorId|constructor_url                             |constructorName|constructor_nationality|fastestLapRank|fastestLapNumber|fastestLapTime|fastestLapAvgSpeed|fastestLapSpeedUnits|
# +------+-----+-----------------------------------------------------+------------------+----------+---------+---------+-----------------------------------------------------------+-----------------------------+-----------+------------+----------------+---------------+------------+--------+------------+------+----+----+--------+-----------+--------------+--------------+---------------+----+----------------------------------------------+---------+----------+-----------+------------------+-------------+--------------------------------------------+---------------+-----------------------+--------------+----------------+--------------+------------------+--------------------+
# |2024  |1    |https://en.wikipedia.org/wiki/2024_Bahrain_Grand_Prix|Bahrain Grand Prix|2024-03-02|15:00:00Z|bahrain  |https://en.wikipedia.org/wiki/Bahrain_International_Circuit|Bahrain International Circuit|26.0325    |50.5106     |Sakhir          |Bahrain        |1           |1       |1           |26    |1   |57  |Finished|1:31:44.742|5504742       |max_verstappen|33             |VER |http://en.wikipedia.org/wiki/Max_Verstappen   |Max      |Verstappen|1997-09-30 |Dutch             |red_bull     |http://en.wikipedia.org/wiki/Red_Bull_Racing|Red Bull       |Austrian               |1             |39              |1:32.608      |210.383           |kph                 |
# |2024  |1    |https://en.wikipedia.org/wiki/2024_Bahrain_Grand_Prix|Bahrain Grand Prix|2024-03-02|15:00:00Z|bahrain  |https://en.wikipedia.org/wiki/Bahrain_International_Circuit|Bahrain International Circuit|26.0325    |50.5106     |Sakhir          |Bahrain        |11          |2       |2           |18    |5   |57  |Finished|+22.457    |5527199       |perez         |11             |PER |http://en.wikipedia.org/wiki/Sergio_P%C3%A9rez|Sergio   |Pérez     |1990-01-26 |Mexican           |red_bull     |http://en.wikipedia.org/wiki/Red_Bull_Racing|Red Bull       |Austrian               |4             |40              |1:34.364      |206.468           |kph                 |
# +------+-----+-----------------------------------------------------+------------------+----------+---------+---------+-----------------------------------------------------------+-----------------------------+-----------+------------+----------------+---------------+------------+--------+------------+------+----+----+--------+-----------+--------------+--------------+---------------+----+----------------------------------------------+---------+----------+-----------+------------------+-------------+--------------------------------------------+---------------+-----------------------+--------------+----------------+--------------+------------------+--------------------+
# only showing top 2 rows
#
# \nTotal number of rows in flattened data: 25474

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/Capstone/tmp/csv/part-00000-58b152f1-76d0-471d-9df3-4ca5b5b318f8-c000.csv',low_memory=False)

# %%
df.head()
# Out:
#    season  round                                           race_url  \
# 0    2024      1  https://en.wikipedia.org/wiki/2024_Bahrain_Gra...
# 1    2024      1  https://en.wikipedia.org/wiki/2024_Bahrain_Gra...
# 2    2024      1  https://en.wikipedia.org/wiki/2024_Bahrain_Gra...
# 3    2024      1  https://en.wikipedia.org/wiki/2024_Bahrain_Gra...
# 4    2024      1  https://en.wikipedia.org/wiki/2024_Bahrain_Gra...
#
#              raceName        date       time circuitId  \
# 0  Bahrain Grand Prix  2024-03-02  15:00:00Z   bahrain
# 1  Bahrain Grand Prix  2024-03-02  15:00:00Z   bahrain
# 2  Bahrain Grand Prix  2024-03-02  15:00:00Z   bahrain
# 3  Bahrain Grand Prix  2024-03-02  15:00:00Z   bahrain
# 4  Bahrain Grand Prix  2024-03-02  15:00:00Z   bahrain
#
#                                          circuit_url  \
# 0  https://en.wikipedia.org/wiki/Bahrain_Internat...
# 1  https://en.wikipedia.org/wiki/Bahrain_Internat...
# 2  https://en.wikipedia.org/wiki/Bahrain_Internat...
# 3  https://en.wikipedia.org/wiki/Bahrain_Internat...
# 4  https://en.wikipedia.org/wiki/Bahrain_Internat...
#
#                      circuitName  circuit_lat  ...  driver_nationality  \
# 0  Bahrain International Circuit      26.0325  ...               Dutch
# 1  Bahrain International Circuit      26.0325  ...             Mexican
# 2  Bahrain International Circuit      26.0325  ...             Spanish
# 3  Bahrain International Circuit      26.0325  ...          Monegasque
# 4  Bahrain International Circuit      26.0325  ...             British
#
#   constructorId                                    constructor_url  \
# 0      red_bull       http://en.wikipedia.org/wiki/Red_Bull_Racing
# 1      red_bull       http://en.wikipedia.org/wiki/Red_Bull_Racing
# 2       ferrari      http://en.wikipedia.org/wiki/Scuderia_Ferrari
# 3       ferrari      http://en.wikipedia.org/wiki/Scuderia_Ferrari
# 4      mercedes  http://en.wikipedia.org/wiki/Mercedes-Benz_in_...
#
#    constructorName  constructor_nationality fastestLapRank  fastestLapNumber  \
# 0         Red Bull                 Austrian            1.0              39.0
# 1         Red Bull                 Austrian            4.0              40.0
# 2          Ferrari                  Italian            6.0              44.0
# 3          Ferrari                  Italian            2.0              36.0
# 4         Mercedes                   German           12.0              40.0
#
#    fastestLapTime  fastestLapAvgSpeed fastestLapSpeedUnits
# 0        1:32.608             210.383                  kph
# 1        1:34.364             206.468                  kph
# 2        1:34.507             206.156                  kph
# 3        1:34.090             207.069                  kph
# 4        1:35.065             204.946                  kph
#
# [5 rows x 39 columns]
